# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime
import time
import pandas as pd

# %%
# Define browser and action setup
PATH= "/chromedriver.exe"
driver = webdriver.Chrome(PATH)

# Define URL
linkedin_url = "https://www.linkedin.com/jobs/search/?keywords=data%20scientist&location=Indonesia"

# Action Steps
driver.maximize_window()
driver.get(linkedin_url) # Open web page

# Determine how many jobs we want to scrape, and calculate how many time we need to scroll down
no_of_jobs = 1500
# int(driver.find_element_by_css_selector("h1>span").get_attribute("innerText"))
n_scroll = int(no_of_jobs/25)+1
print(n_scroll)
i = 1
driver.execute_script("return document.body.scrollHeight") #scroll to top
while i <= n_scroll:
    driver.execute_script("return document.body.scrollHeight")
    time.sleep(2) # wair for 2 seconds
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") #scroll to the bottom of page
    time.sleep(3)
    i = i + 1
    try:
        button = driver.find_element(By.XPATH,"/html/body/div[1]/div/main/section[2]/button")
        #time.sleep(2)
        button.click()
        time.sleep(1)
        print("load more click")
    except:
        driver.execute_script("return document.body.scrollHeight")
        time.sleep(3)

print ("total jobs :")
jobs = driver.find_element(By.CLASS_NAME,"jobs-search__results-list").find_elements(By.TAG_NAME,'li') # return a list
print(len(jobs))
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_32132\4285856292.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
# 61
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# load more click
# total jobs :
# 996

# %%
job_id= []
job_title = []
company_name = []
location = []
date = []
job_link = []
for job in jobs:
    job_id0 = job.get_attribute('data-entity-urn')
    job_id.append(job_id0)

    job_title0 = job.find_element(By.CSS_SELECTOR,'h3').get_attribute('innerText')
    job_title.append(job_title0)

    company_name0 = job.find_element(By.CSS_SELECTOR,'h4').get_attribute('innerText')
    company_name.append(company_name0)

    location0 = job.find_element(By.CLASS_NAME,'job-search-card__location').get_attribute('innerText')
    location.append(location0)

    date0 = job.find_element(By.CSS_SELECTOR,'div>div>time').get_attribute('datetime')
    date.append(date0)

    job_link0 = job.find_element(By.CSS_SELECTOR,'a').get_attribute('href')
    job_link.append(job_link0)

# %%
jd = []
seniority = []
emp_type = []
job_func = []
industries = []
for item in range(len(jobs)):
    job_func0=[]
    industries0=[]
    # clicking job to view job details
    try:
        job_click_path = f'/html/body/div[1]/div/main/section[2]/ul/li[{item+1}]/a/div[1]/img'
        job_click = job.find_element(By.XPATH,job_click_path).click()
    except:
        job_click_path = f'/html/body/div[1]/div/main/section[2]/ul/li[{item+1}]/div/a'
    
    print(job_click_path)
    job_click = job.find_element(By.XPATH,job_click_path).click()
    time.sleep(3)
    try:
        jd_path = '/html/body/div[1]/div/section/div[2]/div/section[1]/div/div/section'
        jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
    except:
        jd_path = '/html/body/div[1]/div/section/div[2]/div/section[2]/div/div/section/div'
    
    jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
    is_benefit = True
    try:
        assert 'Base pay range' in jd0
    except:
        is_benefit = False
        
    if is_benefit==True :
        jd_path = '/html/body/div[1]/div/section/div[2]/div/section[2]/div/div/section/div'
        jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
        jd.append(jd0)
#         print(jd_path)
#         print("appended")
        jd_path2 = '/html/body/div[1]/div/section/div[2]/div/section[2]/div'
    else:
#         print(jd_path)
        jd.append(jd0)
#         print("appended")
        jd_path2 = '/html/body/div[1]/div/section/div[2]/div/section[1]/div'

    try:
        seniority_path = jd_path2 + '/ul/li[1]/span'
        seniority_class_name = 'description__job-criteria-text description__job-criteria-text--criteria'
        #seniority0 = job.find_element(By.XPATH,seniority_path).get_attribute('innerText')
        seniority0 = job.find_element(By.CLASS_NAME,seniority_class_name).get_attribute('innerText')
        seniority.append(seniority0)
    except:
        seniority.append('') #handling if seniority is not available
    
    try:
        emp_type_path = jd_path2 + '/ul/li[2]/span'
        emp_type_class_name = ''
        #emp_type0 = job.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
        emp_type0 = job.find_element(By.CLASS_NAME,emp_type_class_name).get_attribute('innerText')
        emp_type.append(emp_type0)
    except:
        emp_type.append('') #handling if employment type is not available
    
    try:
        job_func_path = jd_path2 + '/ul/li[3]/span'
        job_func_class_name = ''
        #job_func0 = job.find_element(By.XPATH,job_func_path).get_attribute('innerText')
        job_func0 = job.find_element(By.CLASS_NAME,job_func_class_name).get_attribute('innerText')
        job_func.append(job_func0)
    except:
        job_func.append('') #handling if job function is not available
    
    try:
        industries_path = jd_path2 + '/ul/li[4]/span'
        industries_class_name = ''
        #industries0 = job.find_element(By.XPATH,industries_path).get_attribute('innerText')
        emp_type0 = job.find_element(By.CLASS_NAME,industries_class_name).get_attribute('innerText')
        industries.append(industries0)
    except:
        industries.append('')
# Out:
# /html/body/div[1]/div/main/section[2]/ul/li[1]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[2]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[3]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[4]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[5]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[6]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[7]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[8]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[9]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[10]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[11]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[12]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[13]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[14]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[15]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[16]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[17]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[18]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[19]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[20]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[21]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[22]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[23]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[24]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[25]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[26]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[27]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[28]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[29]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[30]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[31]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[32]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[33]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[34]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[35]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[36]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[37]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[38]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[39]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[40]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[41]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[42]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[43]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[44]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[45]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[46]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[47]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[48]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[49]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[50]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[51]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[52]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[53]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[54]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[55]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[56]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[57]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[58]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[59]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[60]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[61]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[62]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[63]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[64]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[65]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[66]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[67]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[68]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[69]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[70]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[71]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[72]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[73]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[74]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[75]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[76]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[77]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[78]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[79]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[80]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[81]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[82]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[83]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[84]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[85]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[86]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[87]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[88]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[89]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[90]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[91]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[92]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[93]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[94]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[95]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[96]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[97]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[98]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[99]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[100]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[101]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[102]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[103]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[104]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[105]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[106]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[107]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[108]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[109]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[110]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[111]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[112]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[113]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[114]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[115]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[116]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[117]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[118]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[119]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[120]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[121]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[122]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[123]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[124]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[125]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[126]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[127]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[128]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[129]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[130]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[131]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[132]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[133]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[134]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[135]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[136]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[137]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[138]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[139]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[140]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[141]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[142]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[143]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[144]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[145]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[146]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[147]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[148]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[149]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[150]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[151]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[152]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[153]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[154]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[155]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[156]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[157]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[158]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[159]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[160]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[161]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[162]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[163]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[164]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[165]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[166]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[167]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[168]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[169]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[170]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[171]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[172]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[173]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[174]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[175]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[176]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[177]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[178]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[179]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[180]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[181]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[182]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[183]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[184]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[185]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[186]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[187]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[188]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[189]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[190]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[191]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[192]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[193]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[194]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[195]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[196]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[197]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[198]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[199]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[200]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[201]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[202]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[203]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[204]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[205]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[206]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[207]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[208]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[209]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[210]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[211]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[212]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[213]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[214]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[215]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[216]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[217]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[218]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[219]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[220]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[221]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[222]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[223]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[224]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[225]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[226]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[227]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[228]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[229]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[230]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[231]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[232]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[233]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[234]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[235]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[236]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[237]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[238]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[239]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[240]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[241]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[242]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[243]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[244]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[245]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[246]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[247]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[248]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[249]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[250]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[251]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[252]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[253]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[254]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[255]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[256]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[257]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[258]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[259]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[260]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[261]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[262]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[263]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[264]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[265]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[266]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[267]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[268]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[269]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[270]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[271]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[272]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[273]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[274]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[275]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[276]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[277]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[278]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[279]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[280]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[281]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[282]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[283]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[284]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[285]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[286]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[287]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[288]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[289]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[290]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[291]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[292]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[293]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[294]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[295]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[296]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[297]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[298]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[299]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[300]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[301]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[302]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[303]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[304]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[305]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[306]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[307]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[308]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[309]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[310]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[311]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[312]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[313]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[314]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[315]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[316]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[317]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[318]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[319]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[320]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[321]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[322]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[323]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[324]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[325]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[326]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[327]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[328]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[329]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[330]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[331]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[332]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[333]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[334]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[335]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[336]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[337]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[338]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[339]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[340]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[341]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[342]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[343]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[344]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[345]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[346]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[347]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[348]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[349]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[350]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[351]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[352]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[353]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[354]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[355]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[356]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[357]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[358]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[359]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[360]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[361]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[362]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[363]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[364]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[365]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[366]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[367]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[368]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[369]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[370]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[371]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[372]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[373]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[374]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[375]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[376]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[377]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[378]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[379]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[380]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[381]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[382]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[383]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[384]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[385]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[386]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[387]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[388]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[389]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[390]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[391]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[392]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[393]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[394]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[395]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[396]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[397]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[398]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[399]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[400]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[401]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[402]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[403]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[404]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[405]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[406]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[407]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[408]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[409]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[410]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[411]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[412]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[413]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[414]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[415]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[416]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[417]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[418]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[419]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[420]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[421]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[422]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[423]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[424]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[425]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[426]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[427]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[428]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[429]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[430]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[431]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[432]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[433]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[434]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[435]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[436]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[437]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[438]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[439]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[440]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[441]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[442]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[443]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[444]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[445]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[446]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[447]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[448]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[449]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[450]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[451]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[452]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[453]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[454]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[455]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[456]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[457]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[458]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[459]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[460]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[461]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[462]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[463]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[464]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[465]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[466]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[467]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[468]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[469]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[470]/div/a
# /html/body/div[1]/div/main/section[2]/ul/li[471]/a/div[1]/img
# /html/body/div[1]/div/main/section[2]/ul/li[472]/div/a
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 25
#      22 except:
#      23     jd_path = '/html/body/div[1]/div/section/div[2]/div/section[2]/div/div/section/div'
# ---> 25 jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
#      26 is_benefit = True
#      27 try:
#
# File c:\Users\ricar\AppData\Local\Programs\Python\Python38\lib\site-packages\selenium\webdriver\remote\webelement.py:425, in WebElement.find_element(self, by, value)
#     422     by = By.CSS_SELECTOR
#     423     value = f'[name="{value}"]'
# --> 425 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ricar\AppData\Local\Programs\Python\Python38\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File c:\Users\ricar\AppData\Local\Programs\Python\Python38\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ricar\AppData\Local\Programs\Python\Python38\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div/section/div[2]/div/section[2]/div/div/section/div"}
#   (Session info: chrome=114.0.5735.91)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x009AA813+48355]
# 	(No symbol) [0x0093C4B1]
# 	(No symbol) [0x00845358]
# 	(No symbol) [0x008709A5]
# 	(No symbol) [0x00870B3B]
# 	(No symbol) [0x00869AE1]
# 	(No symbol) [0x0088A784]
# 	(No symbol) [0x00869A36]
# 	(No symbol) [0x0088AA94]
# 	(No symbol) [0x0089C922]
# 	(No symbol) [0x0088A536]
# 	(No symbol) [0x008682DC]
# 	(No symbol) [0x008693DD]
# 	GetHandleVerifier [0x00C0AABD+2539405]
# 	GetHandleVerifier [0x00C4A78F+2800735]
# 	GetHandleVerifier [0x00C4456C+2775612]
# 	GetHandleVerifier [0x00A351E0+616112]
# 	(No symbol) [0x00945F8C]
# 	(No symbol) [0x00942328]
# 	(No symbol) [0x0094240B]
# 	(No symbol) [0x00934FF7]
# 	BaseThreadInitThunk [0x76497D59+25]
# 	RtlInitializeExceptionChain [0x77D3B74B+107]
# 	RtlClearBits [0x77D3B6CF+191]

# %%
job_data = pd.DataFrame({'ID': job_id,
                        'Date': date,
                        'Company': company_name,
                        'Title': job_title,
                        'Location': location,
                        'Description' : jd,
                        'Level': seniority,
                        'Type': emp_type,
                        'Function': job_func,
                        'Industry': industries
                        })
